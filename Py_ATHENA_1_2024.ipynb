# %% [markdown]
# ## Python Athena Course

# %% [markdown]
#  **What is Python?**
#  Python is a modern, general-purpose, object-oriented, high-level programming language.Most probably you will have read somewhere that the Python language is an interpreted programming or a script language. The truth is: Python is both an interpreted and a compiled language. But calling Python a compiled language would be misleading.

# %% [markdown]
# ### Topic
#     1. Shortcut keys to run the cell
#     2. How to define Variable/Object name - Rule
#     3. How to import the package
#     4. Operators
#        1. Arthmatic
#        2. Comparision
#        3. Logical
#     5. Data types in Python
#     6. String

# %% [markdown]
# ![image.png](attachment:52df397c-11f6-4680-a1e9-d5726584a900.png)

# %% [markdown]
# Python Baiscs -Day 1

# %%
# This is known as  jupyter cell

# %% [markdown]
# ### 1.*Shortcut key*

# %% [markdown]
# 1. shortcut
# 2. for new cell b(below) a (above)
# 3. to deleter cell x
# 4. copy cell c
# 5. paster cell v
# 6. commenting all the line ctrl + /

# %% [markdown]
# ### 2.How to define Variable/Object name - Rule

# %% [markdown]
# #1. Object name must be alpha numeric (a-z and 0-9)
# #2. Object name must start with Alpha.
# #3. Space is not allowed.
# #4. Special char are not allowed @ $ % * &
# #5. Only _ is allowed

# %%
nitin10=10
nitin10  #we can use int after the str
# Out:
# 10

# %%
10nitin=10  #object name should start with alphabet 
10nitin
# Out:
#   Cell In[10], line 1
#     10nitin=10
#      ^
# SyntaxError: invalid decimal literal

# %%
ab nitn=10 #space not allowed
# Out:
#   Cell In[11], line 1
#     ab nitn=10
#        ^
# SyntaxError: invalid syntax

# %%
ab@nitinn=13 #special character not allowed
# Out:
#   Cell In[12], line 1
#     ab@nitinn=13
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
nitin_vyas=10  #only _is allowed

# %%
nitin/vyas=12|
# Out:
#   Cell In[14], line 1
#     nitin/vyas=12|
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
nitin10vyas=10  #in between its ok to have the num 
nitin10vyas
# Out:
# 10

# %% [markdown]
# *python is dynamic*
# if we assign the value to variable and if we assign the new value it will take the latest value

# %%
x=12
y=15
x
# Out:
# 12

# %%
x=12
y=15
x=13
x
# Out:
# 13

# %%
a=b=c=100
a
b
c #all three contain the same value
# Out:
# 100

# %% [markdown]
# *Multiple assignment*   sequence should be like this

# %%
j,k,l=10,20,34

# %%
j
# Out:
# 10

# %%
k
# Out:
# 20

# %%
l
# Out:
# 34

# %%
j,k,l=10,20.5,'boris'

# %%
j,k,l
# Out:
# (10, 20.5, 'boris')

# %%
type(j),type(k),type(l)
# Out:
# (int, float, str)

# %% [markdown]
# ## 3.*How to import the package*

# %% [markdown]
# 1.import math
# 2.import math as mt #(90%)
# 3.from math import *
# 4.from math import cos, log, sqrt, pi, tan #10%

# %%
log(10) # we need to call the package to use this
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 log(10)
#
# NameError: name 'log' is not defined

# %%
import math as mt
mt.log(10)
# Out:
# 2.302585092994046

# %%
mt.sin(20)
# Out:
# 0.9129452507276277

# %% [markdown]
# from math import *
# it will call all the function inside math pacakge and it will become golobal

# %%
#if we don't need to use the alias 
from math import *
cos(30)
# Out:
# 0.15425144988758405

# %%
from math import cos
cos(30),tan(45)
# Out:
# (0.15425144988758405, 1.6197751905438615)

# %% [markdown]
# How to check all the available function in package

# %%
import  math
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %% [markdown]
# #### How get use packages
#
# #step1 - install packages => One time process
# #step2 - load the packages => session specific

# %% [markdown]
# Another way of installation

# %%
# !pip install pandas

# %% [markdown]
# Help(math) this will provide all the function details like syntax with example

# %%
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     cbrt(x, /)
#         Return the cube root of x.
#
# ...

# %% [markdown]
# ### Arthmetic operator

# %%
# +
# -
# * mult
# /  devi       5/2=2.5
# % #Remainder  5/2=1
# ** power
# // int        5/2=2

# %% [markdown]
# ### Comparison Operators

# %%
# ==
# !=
# >
# <
# >=
# <=

# %%
#comparison perators return the result in boolean

# %%
4==2
# Out:
# False

# %%
5<=7
# Out:
# True

# %% [markdown]
# ### Logical Operators

# %%
# and
# or
# not
# in

# %%
5 == 5 and 6 == 90
# Out:
# False

# %%
6 == 6 or 70 > 6
# Out:
# True

# %% [markdown]
# ## Data types in Python

# %%
x = 20 # int
y = 30.767 # float
z = "NIIT" # str
p = 3+6j # complex
c = True # Bool
d = "20 May 2023" #Date

# %%
type(x)
# Out:
# int

# %%
type(p)
# Out:
# complex

# %%
type(d) #this is date format but getting str later will see the package
# Out:
# str

# %%
# Complex data  how to get the real and imaginary no from complex data type 
x = 4 + 20j

# %%
x.real
# Out:
# 4.0

# %%
x.imag
# Out:
# 20.0

# %% [markdown]
# ## Convert

# %%
#syntax for conversion 
# int
int()

# float
float()

# str
str()
# Out:
# ''

# %%
age=40.5
type(age)
# Out:
# float

# %%
age=int(age)
type(age)
# Out:
# int

# %% [markdown]
# ## isinstance => type => data types

# %%
pin=29
isinstance(pin, int)  #isint   return the result in boolean for data types
# Out:
# True

# %%
int=[1,2,3,'A',6]
for i in int:
    print(tuple(isinstance(i, int)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 int=[1,2,3,'A',6]
#       2 for i in int:
# ----> 3     print(tuple(isinstance(i, int)))
#
# TypeError: isinstance() arg 2 must be a type, a tuple of types, or a union

# %%
x = "abc"
type(x)
# Out:
# str

# %%
x = int(x)
# we can convert with cond -
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 x = int(x)
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %% [markdown]
# ### String

# %%
var1 = "Hello World"

# %%
print(dir(var1))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
# Replace
var1 = "Hello World is world "
var2 = var1.replace("Hello World", " Hi India") #replace only the first occurance
print(var2)
# Out:
#  Hi India is world

# %% [markdown]
# # String Subsetting (Slicing)
#
# * **In python Index start from 0 to length -1**
# * **string[start:stop:skip]**

# %%
var2 = 'thor is weak'

var2
# Out:
# 'thor is weak'

# %%
var2[:],var2[1],var2[3:],var2[:-2],var2[-4:-3],var2[::2],var2[::-1]
# Out:
# ('thor is weak', 'h', 'r is weak', 'thor is we', 'w', 'to swa', 'kaew si roht')

# %% [markdown]
# ### Notes from the pdf

# %% [markdown]
# ### **Environment Variable**

# %% [markdown]
# we run python through command prompt

# %% [markdown]
# ![image.png](attachment:7a3e63d6-fea4-496e-8c88-270ae903e4c5.png)

# %% [markdown]
# **@ Questions**

# %%
1.In prompt how to see the path
2.were to put the file 
3.environmnet variable and setting

# %% [markdown]
# Data type
# Arthematic Operation
# Condition statement
